# %%
import os
os.chdir("..")

# %%
from algorithm.RL.DoubleDQN import main

# %%
main({
    "mode" : "test",
    "codes" : ["002303"],
    "market" : "stock",
    "episode"  : 2000,
    "training_data_ratio" : 0.5
})
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-4-fe1edc8e590b> in <module>()
#       4     "market" : "stock",
#       5     "episode"  : 2000,
# ----> 6     "training_data_ratio" : 0.5
#       7 })
#
# D:\workspace\Personae\algorithm\RL\DoubleDQN.py in main(args)
#     165         # "use_sequence": True,
#     166         "logger": generate_market_logger(model_name),
# --> 167         "training_data_ratio": training_data_ratio,
#     168     })
#     169
#
# D:\workspace\Personae\base\env\market.py in __init__(self, codes, start_date, end_date, **options)
#      48
#      49         # Initialize stock data.
# ---> 50         self._init_data(start_date, end_date)
#      51
#      52     def _init_options(self, **options):
#
# D:\workspace\Personae\base\env\market.py in _init_data(self, start_date, end_date)
#     113
# ...
